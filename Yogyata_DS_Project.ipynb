# %%
import pandas as pd
import numpy as np
import seaborn as sns
# Out:
# C:\Users\Archana\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
df=pd.read_csv("C:\\Users\\Archana\\Downloads\\Women Dresses Reviews Dataset .csv")
df
# Out:
#         s.no  age   division_name department_name class_name  clothing_id  \
# 0          0   40         General         Bottoms      Jeans         1028
# 1          1   62  General Petite            Tops    Blouses          850
# 2          2   47  General Petite         Bottoms     Skirts          993
# 3          3   45  General Petite         Bottoms      Pants         1068
# 4          4   37       Initmates        Intimate       Swim           24
# ...      ...  ...             ...             ...        ...          ...
# 23481  23481   44  General Petite         Dresses    Dresses         1081
# 23482  23482   39         General         Dresses    Dresses         1110
# 23483  23483   29  General Petite            Tops      Knits          862
# 23484  23484   57         General         Dresses    Dresses         1082
# 23485  23485   56         General         Jackets    Jackets          984
#
#                                        title  \
# ...

# %%
df.shape
# Out:
# (23486, 11)

# %%
df.head()
# Out:
#    s.no  age   division_name department_name class_name  clothing_id  \
# 0     0   40         General         Bottoms      Jeans         1028
# 1     1   62  General Petite            Tops    Blouses          850
# 2     2   47  General Petite         Bottoms     Skirts          993
# 3     3   45  General Petite         Bottoms      Pants         1068
# 4     4   37       Initmates        Intimate       Swim           24
#
#                     title                                        review_text  \
# 0    Amazing fit and wash  Like other reviewers i was hesitant to spend t...
# 1      Lovely and unique!  As is true of a bunch of the fall clothing pho...
# 2                     Meh  I so wanted this skirt to work, love the desig...
# 3                     Wow  Love love this! i was hesitant to buy this at ...
# 4  Great for bigger busts  I absolutely love the retro look of this swims...
#
#    alike_feedback_count  rating  recommend_index
# ...

# %%
df.tail()
# Out:
#         s.no  age   division_name department_name class_name  clothing_id  \
# 23481  23481   44  General Petite         Dresses    Dresses         1081
# 23482  23482   39         General         Dresses    Dresses         1110
# 23483  23483   29  General Petite            Tops      Knits          862
# 23484  23484   57         General         Dresses    Dresses         1082
# 23485  23485   56         General         Jackets    Jackets          984
#
#                                        title  \
# 23481                               Love it!
# 23482                            Great piece
# 23483                 So soft and flattering
# 23484  Another winner from isabella sinclair
# 23485                                    NaN
#
#                                              review_text  \
# 23481  I oot this dress in the blue. it fits great--h...
# 23482  I was very patient with this dress. i was wait...
# 23483  The deep v doesn't gape, and flatters the neck...
# ...

# %%
df.describe()
# Out:
#                s.no           age   clothing_id  alike_feedback_count  \
# count  23486.000000  23486.000000  23486.000000          23486.000000
# mean   11742.500000     43.198544    918.118709              2.535936
# std     6779.968547     12.279544    203.298980              5.702202
# min        0.000000     18.000000      0.000000              0.000000
# 25%     5871.250000     34.000000    861.000000              0.000000
# 50%    11742.500000     41.000000    936.000000              1.000000
# 75%    17613.750000     52.000000   1078.000000              3.000000
# max    23485.000000     99.000000   1205.000000            122.000000
#
#              rating  recommend_index
# count  23486.000000      23486.000000
# mean       4.196032          0.822362
# std        1.110031          0.382216
# min        1.000000          0.000000
# 25%        4.000000          1.000000
# 50%        5.000000          1.000000
# 75%        5.000000          1.000000
# ...

# %%
df.isnull()
# Out:
#         s.no    age  division_name  department_name  class_name  clothing_id  \
# 0      False  False          False            False       False        False
# 1      False  False          False            False       False        False
# 2      False  False          False            False       False        False
# 3      False  False          False            False       False        False
# 4      False  False          False            False       False        False
# ...      ...    ...            ...              ...         ...          ...
# 23481  False  False          False            False       False        False
# 23482  False  False          False            False       False        False
# 23483  False  False          False            False       False        False
# 23484  False  False          False            False       False        False
# 23485  False  False          False            False       False        False
#
# ...

# %%
df.isnull().sum()
# Out:
# s.no                       0
# age                        0
# division_name             14
# department_name           14
# class_name                14
# clothing_id                0
# title                   3810
# review_text              845
# alike_feedback_count       0
# rating                     0
# recommend_index            0
# dtype: int64

# %%
df1=df['class_name']
# filling missing value using fillna() 
df1.fillna('pink jackets')
#df.fillna(0)
print(df)
# Out:
#         s.no  age   division_name department_name class_name  clothing_id  \
# 0          0   40         General         Bottoms      Jeans         1028
# 1          1   62  General Petite            Tops    Blouses          850
# 2          2   47  General Petite         Bottoms     Skirts          993
# 3          3   45  General Petite         Bottoms      Pants         1068
# 4          4   37       Initmates        Intimate       Swim           24
# ...      ...  ...             ...             ...        ...          ...
# 23481  23481   44  General Petite         Dresses    Dresses         1081
# 23482  23482   39         General         Dresses    Dresses         1110
# 23483  23483   29  General Petite            Tops      Knits          862
# 23484  23484   57         General         Dresses    Dresses         1082
# 23485  23485   56         General         Jackets    Jackets          984
#
#                                        title  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23486 entries, 0 to 23485
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   s.no                  23486 non-null  int64
#  1   age                   23486 non-null  int64
#  2   division_name         23472 non-null  object
#  3   department_name       23472 non-null  object
#  4   class_name            23472 non-null  object
#  5   clothing_id           23486 non-null  int64
#  6   title                 19676 non-null  object
#  7   review_text           22641 non-null  object
#  8   alike_feedback_count  23486 non-null  int64
#  9   rating                23486 non-null  int64
#  10  recommend_index       23486 non-null  int64
# dtypes: int64(6), object(5)
# memory usage: 2.0+ MB

# %%
df.sample()
# Out:
#         s.no  age division_name department_name class_name  clothing_id title  \
# 13814  13814   38       General            Tops      Knits          854   NaN
#
#                                              review_text  \
# 13814  I get so many compliments when i wear this... ...
#
#        alike_feedback_count  rating  recommend_index
# 13814                     0       5                 1

# %%
df.columns
# Out:
# Index(['s.no', 'age', 'division_name', 'department_name', 'class_name',
#        'clothing_id', 'title', 'review_text', 'alike_feedback_count', 'rating',
#        'recommend_index '],
#       dtype='object')

# %%
df.head()
# Out:
#    s.no  age   division_name department_name class_name  clothing_id  \
# 0     0   40         General         Bottoms      Jeans         1028
# 1     1   62  General Petite            Tops    Blouses          850
# 2     2   47  General Petite         Bottoms     Skirts          993
# 3     3   45  General Petite         Bottoms      Pants         1068
# 4     4   37       Initmates        Intimate       Swim           24
#
#                     title                                        review_text  \
# 0    Amazing fit and wash  Like other reviewers i was hesitant to spend t...
# 1      Lovely and unique!  As is true of a bunch of the fall clothing pho...
# 2                     Meh  I so wanted this skirt to work, love the desig...
# 3                     Wow  Love love this! i was hesitant to buy this at ...
# 4  Great for bigger busts  I absolutely love the retro look of this swims...
#
#    alike_feedback_count  rating  recommend_index
# ...

# %%
df.tail()
# Out:
#         s.no  age   division_name department_name class_name  clothing_id  \
# 23481  23481   44  General Petite         Dresses    Dresses         1081
# 23482  23482   39         General         Dresses    Dresses         1110
# 23483  23483   29  General Petite            Tops      Knits          862
# 23484  23484   57         General         Dresses    Dresses         1082
# 23485  23485   56         General         Jackets    Jackets          984
#
#                                        title  \
# 23481                               Love it!
# 23482                            Great piece
# 23483                 So soft and flattering
# 23484  Another winner from isabella sinclair
# 23485                                    NaN
#
#                                              review_text  \
# 23481  I oot this dress in the blue. it fits great--h...
# 23482  I was very patient with this dress. i was wait...
# 23483  The deep v doesn't gape, and flatters the neck...
# ...

# %%
df.isnull()
# Out:
#         s.no    age  division_name  department_name  class_name  clothing_id  \
# 0      False  False          False            False       False        False
# 1      False  False          False            False       False        False
# 2      False  False          False            False       False        False
# 3      False  False          False            False       False        False
# 4      False  False          False            False       False        False
# ...      ...    ...            ...              ...         ...          ...
# 23481  False  False          False            False       False        False
# 23482  False  False          False            False       False        False
# 23483  False  False          False            False       False        False
# 23484  False  False          False            False       False        False
# 23485  False  False          False            False       False        False
#
# ...

# %%
#String Operation on column department_name

# %%
#Substring
df['department_name'][0:5].str.extract('(\wt)')
# Out:
#      0
# 0   ot
# 1  NaN
# 2   ot
# 3   ot
# 4   nt

# %%
#Filtering
df[df['department_name']=='Bottoms']
# Out:
#         s.no  age   division_name department_name class_name  clothing_id  \
# 0          0   40         General         Bottoms      Jeans         1028
# 2          2   47  General Petite         Bottoms     Skirts          993
# 3          3   45  General Petite         Bottoms      Pants         1068
# 12        12   53         General         Bottoms     Skirts         1008
# 13        13   23         General         Bottoms     Skirts         1020
# ...      ...  ...             ...             ...        ...          ...
# 23458  23458   36         General         Bottoms     Skirts         1003
# 23464  23464   54  General Petite         Bottoms      Pants         1068
# 23469  23469   42         General         Bottoms     Shorts          456
# 23474  23474   46         General         Bottoms      Jeans         1030
# 23475  23475   25  General Petite         Bottoms     Skirts         1008
#
#                                            title  \
# ...

# %%
#Uppercase
df['department_name'][0:10].str.upper()
# Out:
# 0     BOTTOMS
# 1        TOPS
# 2     BOTTOMS
# 3     BOTTOMS
# 4    INTIMATE
# 5        TOPS
# 6        TOPS
# 7        TOPS
# 8        TOPS
# 9        TOPS
# Name: department_name, dtype: object

# %%
#Lowercase
df['department_name'][0:10].str.lower()
# Out:
# 0     bottoms
# 1        tops
# 2     bottoms
# 3     bottoms
# 4    intimate
# 5        tops
# 6        tops
# 7        tops
# 8        tops
# 9        tops
# Name: department_name, dtype: object

# %%
#Split
df['department_name'].str.split(',')
# Out:
# 0         [Bottoms]
# 1            [Tops]
# 2         [Bottoms]
# 3         [Bottoms]
# 4        [Intimate]
#             ...
# 23481     [Dresses]
# 23482     [Dresses]
# 23483        [Tops]
# 23484     [Dresses]
# 23485     [Jackets]
# Name: department_name, Length: 23486, dtype: object

# %%
#Data Operation

# %%
#Average
data=df[df['title']=='Wow']
data['rating'].mean()
# Out:
# 5.0

# %%
#Total
data['rating'].sum()
# Out:
# 35

# %%
#Maximum value
data['rating'].max()
# Out:
# 5

# %%
#Minimum
data['rating'].min()
# Out:
# 5

# %%
#Standard Deviation
data['rating'].std()
# Out:
# 0.0

# %%
#Count
data['rating'].count()
# Out:
# 7

# %%
df['division_name'].value_counts()
# Out:
# General           13850
# General Petite     8120
# Initmates          1502
# Name: division_name, dtype: int64

# %%
df.department_name.value_counts()
# Out:
# Tops        10468
# Dresses      6319
# Bottoms      3799
# Intimate     1735
# Jackets      1032
# Trend         119
# Name: department_name, dtype: int64

# %%
#Cleaning Data
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 23481    False
# 23482    False
# 23483    False
# 23484    False
# 23485    False
# Length: 23486, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull()
# Out:
#         s.no    age  division_name  department_name  class_name  clothing_id  \
# 0      False  False          False            False       False        False
# 1      False  False          False            False       False        False
# 2      False  False          False            False       False        False
# 3      False  False          False            False       False        False
# 4      False  False          False            False       False        False
# ...      ...    ...            ...              ...         ...          ...
# 23481  False  False          False            False       False        False
# 23482  False  False          False            False       False        False
# 23483  False  False          False            False       False        False
# 23484  False  False          False            False       False        False
# 23485  False  False          False            False       False        False
#
# ...

# %%
df.isnull().sum()
# Out:
# s.no                       0
# age                        0
# division_name             14
# department_name           14
# class_name                14
# clothing_id                0
# title                   3810
# review_text              845
# alike_feedback_count       0
# rating                     0
# recommend_index            0
# dtype: int64

# %%
df.drop_duplicates(subset=None,keep='first',inplace=True)
df.duplicated().sum()
# Out:
# 0

# %%
#Dropping the serial no. colunm because the index no. and serial no is same . So we can access our data by using index no.

# %%
#RelationShip between variable

# %%
corr=df.corr()
sns.heatmap(corr,annot=True,cmap='Reds')
# Out:
# <AxesSubplot:>
