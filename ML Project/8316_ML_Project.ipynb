# %% [markdown]
# # 8316 Yogyata A. Chaubey
# # ML Project : Mumbai House Price Prediction

# %%
# Importing requried libraray
import pandas as pd 
import numpy as np

# %%
data = pd.read_csv('Mumbai House Prices.csv')

# %%
data = pd.DataFrame(data)
data
# Out:
#        bhk       type                              locality  area  price  \
# 0        3  Apartment   Lak And Hanware The Residency Tower   685   2.50
# 1        2  Apartment     Radheya Sai Enclave Building No 2   640  52.51
# 2        2  Apartment                         Romell Serene   610   1.73
# 3        2  Apartment  Soundlines Codename Urban Rainforest   876  59.98
# 4        2  Apartment                         Origin Oriana   659  94.11
# ...    ...        ...                                   ...   ...    ...
# 76033    3  Apartment                     Parinee Liva Roca  1527   7.00
# 76034    5  Apartment                     Parinee Liva Roca  3049  12.00
# 76035    4  Apartment                         Lodha Seaview  3313  10.00
# 76036    2  Apartment                        Hubtown Serene  1305   4.25
# 76037    5  Apartment              Sunteck Signature Island  5200  25.00
#
#       price_unit                region              status      age
# ...

# %%
data.shape
# Out:
# (76038, 9)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76038 entries, 0 to 76037
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bhk         76038 non-null  int64
#  1   type        76038 non-null  object
#  2   locality    76038 non-null  object
#  3   area        76038 non-null  int64
#  4   price       76038 non-null  float64
#  5   price_unit  76038 non-null  object
#  6   region      76038 non-null  object
#  7   status      76038 non-null  object
#  8   age         76038 non-null  object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 5.2+ MB

# %%
# Displaying unique value counts for each column in the DataFrame
for column in data.columns:
    print(data[column].value_counts())
    print("*"*20)
# Out:
# bhk
# 2     31429
# 1     24613
# 3     15273
# 4      3934
# 5       606
# 6       148
# 7        16
# 8         8
# 10        6
# 9         5
# Name: count, dtype: int64
# ********************
# type
# Apartment            74854
# Studio Apartment       882
# Villa                  226
# Independent House       73
# Penthouse                3
# Name: count, dtype: int64
# ********************
# locality
# Hiranandani Meadows                    861
# Sheth Avalon                           516
# T Bhimjyani The Verraton               499
# ACME Ozone Phase 2                     467
# Runwal Gardens                         389
#                                       ...
# HP Anton CHSL Rishab Anton               1
# Reputed Builder Shankar Heritage         1
# Reputed Builder Aishwarya Apartment      1
# Reputed Builder Vinit Tower              1
# Hubtown Serene                           1
# Name: count, Length: 9782, dtype: int64
# ********************
# area
# 650     1662
# ...

# %%
# Checking the null value
data.isna().sum()
# Out:
# bhk           0
# type          0
# locality      0
# area          0
# price         0
# price_unit    0
# region        0
# status        0
# age           0
# dtype: int64

# %%
# Removing unnecessary columns
data.drop(columns=['locality','status','age'],inplace=True)

# %%
# Inserting new column Amount in the DataFrame
data["Amount"] = data['price'].astype(str) +" "+ data["price_unit"]
data.head()
# Out:
#    bhk       type  area  price price_unit          region   Amount
# 0    3  Apartment   685   2.50         Cr    Andheri West   2.5 Cr
# 1    2  Apartment   640  52.51          L    Naigaon East  52.51 L
# 2    2  Apartment   610   1.73         Cr   Borivali West  1.73 Cr
# 3    2  Apartment   876  59.98          L          Panvel  59.98 L
# 4    2  Apartment   659  94.11          L  Mira Road East  94.11 L

# %%
# Converting Crore value in Lakhs
def fun(x):
    if 'Cr' in x or 'cr' in x:
        s=str(x).split(" ")[0]
        s1=str(int(float(s)*100))
        return s1
    else:
        s=str(x).split(" ")[0]
        return s

# %%
# Converting 'Amount' column to standardized format usinf fun()
data['Amount']=data['Amount'].map(lambda x:fun(x))
data['Amount']
# Out:
# 0          250
# 1        52.51
# 2          173
# 3        59.98
# 4        94.11
#          ...
# 76033      700
# 76034     1200
# 76035     1000
# 76036      425
# 76037     2500
# Name: Amount, Length: 76038, dtype: object

# %%
data=data.drop(['price','price_unit'],axis='columns')
data.shape
# Out:
# (76038, 5)

# %%
data.head()
# Out:
#    bhk       type  area          region Amount
# 0    3  Apartment   685    Andheri West    250
# 1    2  Apartment   640    Naigaon East  52.51
# 2    2  Apartment   610   Borivali West    173
# 3    2  Apartment   876          Panvel  59.98
# 4    2  Apartment   659  Mira Road East  94.11

# %%
data = data.rename({'Amount': 'Price_in_Lakhs'}, axis='columns')
data.head()
# Out:
#    bhk       type  area          region Price_in_Lakhs
# 0    3  Apartment   685    Andheri West            250
# 1    2  Apartment   640    Naigaon East          52.51
# 2    2  Apartment   610   Borivali West            173
# 3    2  Apartment   876          Panvel          59.98
# 4    2  Apartment   659  Mira Road East          94.11

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76038 entries, 0 to 76037
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   bhk             76038 non-null  int64
#  1   type            76038 non-null  object
#  2   area            76038 non-null  int64
#  3   region          76038 non-null  object
#  4   Price_in_Lakhs  76038 non-null  object
# dtypes: int64(2), object(3)
# memory usage: 2.9+ MB

# %%
# Converting obj Dtypes to float
data['Price_in_Lakhs'] = data['Price_in_Lakhs'].astype(float)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76038 entries, 0 to 76037
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   bhk             76038 non-null  int64
#  1   type            76038 non-null  object
#  2   area            76038 non-null  int64
#  3   region          76038 non-null  object
#  4   Price_in_Lakhs  76038 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 2.9+ MB

# %%
data.describe()
# Out:
#                 bhk          area  Price_in_Lakhs
# count  76038.000000  76038.000000    76038.000000
# mean       2.015111   1024.536850      168.383221
# std        0.922754    670.276165      217.657958
# min        1.000000    127.000000        4.490000
# 25%        1.000000    640.000000       64.000000
# 50%        2.000000    872.000000      110.000000
# 75%        3.000000   1179.000000      194.000000
# max       10.000000  16000.000000     6000.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76038 entries, 0 to 76037
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   bhk             76038 non-null  int64
#  1   type            76038 non-null  object
#  2   area            76038 non-null  int64
#  3   region          76038 non-null  object
#  4   Price_in_Lakhs  76038 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 2.9+ MB

# %%
data['region'].value_counts()
# Out:
# region
# Thane West         14868
# Mira Road East      9902
# Dombivali           3041
# Kandivali East      2568
# Kharghar            2362
#                    ...
# Police Colony          1
# GTB Nagar              1
# Bandra                 1
# Sector 14 Vashi        1
# Goregaon               1
# Name: count, Length: 228, dtype: int64

# %%
data.isna().sum()
# Out:
# bhk               0
# type              0
# area              0
# region            0
# Price_in_Lakhs    0
# dtype: int64

# %%
data['bhk'].value_counts()
# Out:
# bhk
# 2     31429
# 1     24613
# 3     15273
# 4      3934
# 5       606
# 6       148
# 7        16
# 8         8
# 10        6
# 9         5
# Name: count, dtype: int64

# %%
data['area'].unique()
# Out:
# array([ 685,  640,  610, ..., 1974, 1634, 3049], dtype=int64)

# %%
# Converting area int into float
data['area'] = data['area'].astype(float)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76038 entries, 0 to 76037
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   bhk             76038 non-null  int64
#  1   type            76038 non-null  object
#  2   area            76038 non-null  float64
#  3   region          76038 non-null  object
#  4   Price_in_Lakhs  76038 non-null  float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 2.9+ MB

# %%
# Price per Square feet
data['price_per_sqft']=data['Price_in_Lakhs']*100000/data['area']

# %%
data['price_per_sqft']
# Out:
# 0        36496.350365
# 1         8204.687500
# 2        28360.655738
# 3         6847.031963
# 4        14280.728376
#              ...
# 76033    45841.519319
# 76034    39357.166284
# 76035    30184.123151
# 76036    32567.049808
# 76037    48076.923077
# Name: price_per_sqft, Length: 76038, dtype: float64

# %%
data.describe()
# Out:
#                 bhk          area  Price_in_Lakhs  price_per_sqft
# count  76038.000000  76038.000000    76038.000000    76038.000000
# mean       2.015111   1024.536850      168.383221    15115.255133
# std        0.922754    670.276165      217.657958     9331.123795
# min        1.000000    127.000000        4.490000      646.766169
# 25%        1.000000    640.000000       64.000000     8571.428571
# 50%        2.000000    872.000000      110.000000    13000.000000
# 75%        3.000000   1179.000000      194.000000    19487.179487
# max       10.000000  16000.000000     6000.000000   182307.692308

# %%
data['region'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0                Andheri West
# 1                Naigaon East
# 2               Borivali West
# 3                      Panvel
# 4              Mira Road East
#                  ...
# 76033                    Juhu
# 76034                    Juhu
# 76035          Napeansea Road
# 76036             Bandra East
# 76037    Bandra Kurla Complex
# Name: region, Length: 76038, dtype: object>

# %%
# Removing extra spaces from the 'region' column
data['region']=data['region'].apply(lambda x: x.strip())
region_count=data['region'].value_counts()

# %%
region_count
# Out:
# region
# Thane West         14868
# Mira Road East      9902
# Dombivali           3041
# Kandivali East      2568
# Kharghar            2362
#                    ...
# Police Colony          1
# GTB Nagar              1
# Bandra                 1
# Sector 14 Vashi        1
# Goregaon               1
# Name: count, Length: 228, dtype: int64

# %%
region_count_less_5 = region_count[region_count<=5]
region_count_less_5
# Out:
# region
# Sector 19 Kamothe     5
# Dahisar East          5
# Fort                  5
# Navade                5
# Sector 19 Kharghar    4
#                      ..
# Police Colony         1
# GTB Nagar             1
# Bandra                1
# Sector 14 Vashi       1
# Goregaon              1
# Name: count, Length: 95, dtype: int64

# %%
# Assuming to categorize regions with less than 5 occurrences as 'other'
region_counts = data['region'].value_counts()
region_count_less_5 = region_counts[region_counts < 5].index.tolist()

data['region'] = data['region'].apply(lambda x: 'other' if x in region_count_less_5 else x)

# %%
data['region'].value_counts()
# Out:
# region
# Thane West           14868
# Mira Road East        9902
# Dombivali             3041
# Kandivali East        2568
# Kharghar              2362
#                      ...
# Sector 17 Ulwe           6
# Navade                   5
# Dahisar East             5
# Fort                     5
# Sector 19 Kamothe        5
# Name: count, Length: 138, dtype: int64

# %%
data['region'].nunique()
# Out:
# 138

# %%
data.describe()
# Out:
#                 bhk          area  Price_in_Lakhs  price_per_sqft
# count  76038.000000  76038.000000    76038.000000    76038.000000
# mean       2.015111   1024.536850      168.383221    15115.255133
# std        0.922754    670.276165      217.657958     9331.123795
# min        1.000000    127.000000        4.490000      646.766169
# 25%        1.000000    640.000000       64.000000     8571.428571
# 50%        2.000000    872.000000      110.000000    13000.000000
# 75%        3.000000   1179.000000      194.000000    19487.179487
# max       10.000000  16000.000000     6000.000000   182307.692308

# %%
# Calculating how many sqft require in a bhk
(data['area']/data['bhk']).describe()
# Out:
# count    76038.000000
# mean       513.278131
# std        161.417111
# min        127.000000
# 25%        403.500000
# 50%        502.500000
# 75%        600.000000
# max       4930.000000
# dtype: float64

# %%
# Exclude rows where 'bhk' is zero to avoid division by zero
data = data[data['bhk'] != 0]  
data = data[(data['area'] / data['bhk']) >= 300]

# Now,proceed with the describe function
data.describe()
# Out:
#                 bhk          area  Price_in_Lakhs  price_per_sqft
# count  71567.000000  71567.000000    71567.000000    71567.000000
# mean       2.006665   1052.869311      172.353681    14942.691305
# std        0.936963    679.476429      223.170724     9378.200461
# min        1.000000    300.000000        4.490000      646.766169
# 25%        1.000000    651.000000       64.500000     8454.545455
# 50%        2.000000    905.000000      111.000000    12727.272727
# 75%        3.000000   1200.000000      200.000000    19142.638372
# max       10.000000  16000.000000     6000.000000   182307.692308

# %%
data.shape
# Out:
# (71567, 6)

# %%
data.price_per_sqft.describe()
# Out:
# count     71567.000000
# mean      14942.691305
# std        9378.200461
# min         646.766169
# 25%        8454.545455
# 50%       12727.272727
# 75%       19142.638372
# max      182307.692308
# Name: price_per_sqft, dtype: float64

# %%
# Removing outlier from the price_per_sqft
def remove_outliers_sqft(df):
    df_output = pd.DataFrame()
    for key,subdf in df.groupby('region'):
        m=np.mean(subdf.price_per_sqft)
        
        st=np.std(subdf.price_per_sqft)
        gen_df=subdf[(subdf.price_per_sqft > (m-st)) & (subdf.price_per_sqft <= (m+st))]
        df_output=pd.concat([df_output,gen_df],ignore_index=True)
    return df_output

data=remove_outliers_sqft(data)
data.describe()
# Out:
#               bhk          area  Price_in_Lakhs  price_per_sqft
# count  6246.00000   6246.000000     6246.000000     6246.000000
# mean      2.20333   1110.534582      210.648455    17802.734740
# std       0.99894    790.605008      249.003937     9774.825524
# min       1.00000    300.000000       15.000000     3903.903904
# 25%       1.00000    639.000000       79.200000    10588.235294
# 50%       2.00000    905.000000      145.500000    16705.882353
# 75%       3.00000   1250.000000      269.750000    23367.928368
# max      10.00000  10893.000000     5555.000000    67307.692308

# %%
# Removing bhk outlier if no of bhk count is less than 5 then exclude that bhk
def bhk_outlier_remover(df):
    exclude_indices=np.array([])
    for region,region_df in df.groupby('region'):
        bhk_stats={}
        for bhk,bhk_df in region_df.groupby('bhk'):
            bhk_stats[bhk]={
                'mean':np.mean(bhk_df.price_per_sqft),
                'std':np.std(bhk_df.price_per_sqft),
                'count':bhk_df.shape[0]
            }
            
        for bhk,bhk_df in region_df.groupby('bhk'):
            stats = bhk_stats.get(bhk-1)
            if stats and stats['count']>5:
                exclude_indices=np.append(exclude_indices,bhk_df[bhk_df.price_per_sqft<(stats['mean'])].index.values)
    return df.drop(exclude_indices,axis='index')

# %%
data=bhk_outlier_remover(data)

# %%
data.shape
# Out:
# (4244, 6)

# %%
data
# Out:
#       bhk       type    area    region  Price_in_Lakhs  price_per_sqft
# 0       2  Apartment   650.0  Agripada           262.0    40307.692308
# 1       4  Apartment  3454.0  Agripada          1250.0    36189.924725
# 2       3  Apartment  1400.0  Agripada           570.0    40714.285714
# 3       2  Apartment  1479.0  Agripada           500.0    33806.626099
# 4       3  Apartment  1850.0    Airoli           310.0    16756.756757
# ...   ...        ...     ...       ...             ...             ...
# 6241    2  Apartment  1120.0     other           254.0    22678.571429
# 6242    3  Apartment  1150.0     other           240.0    20869.565217
# 6243    3  Apartment  1350.0     other           285.0    21111.111111
# 6244    1  Apartment   527.0     other           110.0    20872.865275
# 6245    3  Apartment  1450.0     other           264.0    18206.896552
#
# [4244 rows x 6 columns]

# %%
data.drop(columns=['price_per_sqft'],inplace=True)

# %%
# Cleaned Data
data.head()
# Out:
#    bhk       type    area    region  Price_in_Lakhs
# 0    2  Apartment   650.0  Agripada           262.0
# 1    4  Apartment  3454.0  Agripada          1250.0
# 2    3  Apartment  1400.0  Agripada           570.0
# 3    2  Apartment  1479.0  Agripada           500.0
# 4    3  Apartment  1850.0    Airoli           310.0

# %%
# Saving clean data in .csv file
data.to_csv("Cleaned_data.csv")

# %%
X=data.drop(columns=['Price_in_Lakhs'])
y=data['Price_in_Lakhs']

# %%
# Importing required libraries
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression,Lasso,Ridge
from sklearn.preprocessing import OneHotEncoder,StandardScaler
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.metrics import r2_score

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (4839, 4)
# (1210, 4)

# %%
print(X_train.columns)
print(X_test.columns)
# Out:
# Index(['bhk', 'type', 'area', 'region'], dtype='object')
# Index(['bhk', 'type', 'area', 'region'], dtype='object')

# %%
all_regions = pd.concat([X_train['region'], X_test['region']])

# %%
# Applying Linear Regression
column_trans=make_column_transformer((OneHotEncoder(sparse_output=False,drop='first',
                                                    handle_unknown='ignore'),['type', 'region']),
                                       (StandardScaler(), ['bhk', 'area']),
                                        remainder='passthrough')

# %%
scaler=StandardScaler()

# %%
lr=LinearRegression()

# %%
pipe = make_pipeline(column_trans,scaler,lr)

# %%
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   ['type', 'region']),
#                                                  ('standardscaler',
#                                                   StandardScaler(),
#                                                   ['bhk', 'area'])])),
#                 ('standardscaler', StandardScaler()),
#                 ('linearregression', LinearRegression())])

# %%
y_pred_lr=pipe.predict(X_test)
# Out:
# C:\Users\Archana\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:241: UserWarning: Found unknown categories in columns [1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
r2_score(y_test,y_pred_lr)
# Out:
# 0.8684195521332123

# %%
# Applying Lasso : L1 regularization
lasso=Lasso()

# %%
pipe=make_pipeline(column_trans,lasso)

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   ['type', 'region']),
#                                                  ('standardscaler',
#                                                   StandardScaler(),
#                                                   ['bhk', 'area'])])),
#                 ('lasso', Lasso())])

# %%
y_pred_lasso=pipe.predict(X_test)

r2_score(y_test,y_pred_lasso)
# Out:
# C:\Users\Archana\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:241: UserWarning: Found unknown categories in columns [1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# 0.7809430230961302

# %%
# Applying Ridge : L2 regularization
ridge=Ridge()

# %%
pipe=make_pipeline(column_trans,ridge)

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   ['type', 'region']),
#                                                  ('standardscaler',
#                                                   StandardScaler(),
#                                                   ['bhk', 'area'])])),
#                 ('ridge', Ridge())])

# %%
y_pred_ridge=pipe.predict(X_test)

r2_score(y_test,y_pred_ridge)
# Out:
# C:\Users\Archana\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:241: UserWarning: Found unknown categories in columns [1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# 0.8664242920859302

# %%
print("No Regularization: ",r2_score(y_test,y_pred_lr))
print("Lasso : ",r2_score(y_test,y_pred_lasso))
print("Ridge : ",r2_score(y_test,y_pred_ridge))
# Out:
# No Regularization:  0.8684195521332123
# Lasso :  0.7809430230961302
# Ridge :  0.8664242920859302

# %%
import pickle

# %%
pickle.dump(pipe,open('RidgeModel.pkl','wb'))
