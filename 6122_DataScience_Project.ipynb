# %%
# Name : Yogyata Ajaykumar Chaubey
# Roll no. : 6122
# Division : A
# Topic : Women Dresses Reviews Dataset

# %%
# Importing the all libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# C:\Users\Archana\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# Loading the dataset
data=pd.read_csv("C:\\Users\\Archana\\Downloads\\Women Dresses Reviews Dataset .csv")
data
# Out:
#         s.no  age   division_name department_name class_name  clothing_id  \
# 0          0   40         General         Bottoms      Jeans         1028
# 1          1   62  General Petite            Tops    Blouses          850
# 2          2   47  General Petite         Bottoms     Skirts          993
# 3          3   45  General Petite         Bottoms      Pants         1068
# 4          4   37       Initmates        Intimate       Swim           24
# ...      ...  ...             ...             ...        ...          ...
# 23481  23481   44  General Petite         Dresses    Dresses         1081
# 23482  23482   39         General         Dresses    Dresses         1110
# 23483  23483   29  General Petite            Tops      Knits          862
# 23484  23484   57         General         Dresses    Dresses         1082
# 23485  23485   56         General         Jackets    Jackets          984
#
#                                        title  \
# ...

# %%
# Printing total no. of rows and columns
data.shape
# Out:
# (23486, 11)

# %%
# Printing top 5 value
data.head()
# Out:
#    s.no  age   division_name department_name class_name  clothing_id  \
# 0     0   40         General         Bottoms      Jeans         1028
# 1     1   62  General Petite            Tops    Blouses          850
# 2     2   47  General Petite         Bottoms     Skirts          993
# 3     3   45  General Petite         Bottoms      Pants         1068
# 4     4   37       Initmates        Intimate       Swim           24
#
#                     title                                        review_text  \
# 0    Amazing fit and wash  Like other reviewers i was hesitant to spend t...
# 1      Lovely and unique!  As is true of a bunch of the fall clothing pho...
# 2                     Meh  I so wanted this skirt to work, love the desig...
# 3                     Wow  Love love this! i was hesitant to buy this at ...
# 4  Great for bigger busts  I absolutely love the retro look of this swims...
#
#    alike_feedback_count  rating  recommend_index
# ...

# %%
# Printing bottom 5 value
data.tail()
# Out:
#         s.no  age   division_name department_name class_name  clothing_id  \
# 23481  23481   44  General Petite         Dresses    Dresses         1081
# 23482  23482   39         General         Dresses    Dresses         1110
# 23483  23483   29  General Petite            Tops      Knits          862
# 23484  23484   57         General         Dresses    Dresses         1082
# 23485  23485   56         General         Jackets    Jackets          984
#
#                                        title  \
# 23481                               Love it!
# 23482                            Great piece
# 23483                 So soft and flattering
# 23484  Another winner from isabella sinclair
# 23485                                    NaN
#
#                                              review_text  \
# 23481  I oot this dress in the blue. it fits great--h...
# 23482  I was very patient with this dress. i was wait...
# 23483  The deep v doesn't gape, and flatters the neck...
# ...

# %%
# Printing the sample of data
data.sample()
# Out:
#         s.no  age division_name department_name class_name  clothing_id  \
# 12969  12969   41       General         Bottoms      Jeans         1038
#
#                                title  \
# 12969  So unique and so comfortable!
#
#                                              review_text  \
# 12969  I love these jeans! when i saw them in my reta...
#
#        alike_feedback_count  rating  recommend_index
# 12969                     1       5                 1

# %%
# Printing all Columns name
data.columns
# Out:
# Index(['s.no', 'age', 'division_name', 'department_name', 'class_name',
#        'clothing_id', 'title', 'review_text', 'alike_feedback_count', 'rating',
#        'recommend_index '],
#       dtype='object')

# %%
# Total no. of colunm
len(data.columns)
# Out:
# 11

# %%
# Printing information about columns
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23486 entries, 0 to 23485
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   s.no                  23486 non-null  int64
#  1   age                   23486 non-null  int64
#  2   division_name         23472 non-null  object
#  3   department_name       23472 non-null  object
#  4   class_name            23472 non-null  object
#  5   clothing_id           23486 non-null  int64
#  6   title                 19676 non-null  object
#  7   review_text           22641 non-null  object
#  8   alike_feedback_count  23486 non-null  int64
#  9   rating                23486 non-null  int64
#  10  recommend_index       23486 non-null  int64
# dtypes: int64(6), object(5)
# memory usage: 2.0+ MB

# %%
# It does not include NaN value
data.count()
# Out:
# s.no                    23486
# age                     23486
# division_name           23472
# department_name         23472
# class_name              23472
# clothing_id             23486
# title                   19676
# review_text             22641
# alike_feedback_count    23486
# rating                  23486
# recommend_index         23486
# dtype: int64

# %%
# describe() : returns description of the data 
data.describe()
# Out:
#                s.no           age   clothing_id  alike_feedback_count  \
# count  23486.000000  23486.000000  23486.000000          23486.000000
# mean   11742.500000     43.198544    918.118709              2.535936
# std     6779.968547     12.279544    203.298980              5.702202
# min        0.000000     18.000000      0.000000              0.000000
# 25%     5871.250000     34.000000    861.000000              0.000000
# 50%    11742.500000     41.000000    936.000000              1.000000
# 75%    17613.750000     52.000000   1078.000000              3.000000
# max    23485.000000     99.000000   1205.000000            122.000000
#
#              rating  recommend_index
# count  23486.000000      23486.000000
# mean       4.196032          0.822362
# std        1.110031          0.382216
# min        1.000000          0.000000
# 25%        4.000000          1.000000
# 50%        5.000000          1.000000
# 75%        5.000000          1.000000
# ...

# %%
# Count no. numarical column
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

data1 = data.select_dtypes(include=numerics)
len(data1.columns)
# Out:
# 6

# %%
# nunique(): returns the number of unique values for each column
data.nunique()
# Out:
# s.no                    23486
# age                        77
# division_name               3
# department_name             6
# class_name                 20
# clothing_id              1206
# title                   13993
# review_text             22634
# alike_feedback_count       82
# rating                      5
# recommend_index             2
# dtype: int64

# %%
# String Operation :

# %%
#Substring
data['department_name'][0:5].str.extract('(\wt)')
# Out:
#      0
# 0   ot
# 1  NaN
# 2   ot
# 3   ot
# 4   nt

# %%
#Filtering
data[data['department_name']=='Bottoms'].head(10)
# Out:
#     s.no  age   division_name department_name class_name  clothing_id  \
# 0      0   40         General         Bottoms      Jeans         1028
# 2      2   47  General Petite         Bottoms     Skirts          993
# 3      3   45  General Petite         Bottoms      Pants         1068
# 12    12   53         General         Bottoms     Skirts         1008
# 13    13   23         General         Bottoms     Skirts         1020
# 18    18   50  General Petite         Bottoms      Pants         1060
# 21    21   38         General         Bottoms      Pants         1053
# 22    22   34         General         Bottoms     Shorts          177
# 30    30   42         General         Bottoms      Pants         1056
# 31    31   35         General         Bottoms      Pants         1063
#
#                           title  \
# 0          Amazing fit and wash
# 2                           Meh
# 3                           Wow
# 12       Not red, not orange...
# ...

# %%
#Uppercase
data['department_name'][0:10].str.upper()
# Out:
# 0     BOTTOMS
# 1        TOPS
# 2     BOTTOMS
# 3     BOTTOMS
# 4    INTIMATE
# 5        TOPS
# 6        TOPS
# 7        TOPS
# 8        TOPS
# 9        TOPS
# Name: department_name, dtype: object

# %%
#Lowercase
data['department_name'][0:10].str.lower()
# Out:
# 0     bottoms
# 1        tops
# 2     bottoms
# 3     bottoms
# 4    intimate
# 5        tops
# 6        tops
# 7        tops
# 8        tops
# 9        tops
# Name: department_name, dtype: object

# %%
#Splitting method
data['department_name'].str.split('')
# Out:
# 0           [, B, o, t, t, o, m, s, ]
# 1                    [, T, o, p, s, ]
# 2           [, B, o, t, t, o, m, s, ]
# 3           [, B, o, t, t, o, m, s, ]
# 4        [, I, n, t, i, m, a, t, e, ]
#                      ...
# 23481       [, D, r, e, s, s, e, s, ]
# 23482       [, D, r, e, s, s, e, s, ]
# 23483                [, T, o, p, s, ]
# 23484       [, D, r, e, s, s, e, s, ]
# 23485       [, J, a, c, k, e, t, s, ]
# Name: department_name, Length: 23486, dtype: object

# %%
# Data Operation

# %%
#Average
df=data[data['title']=='Wow']
df['rating'].mean()
# Out:
# 5.0

# %%
#Total
data['rating'].sum()
# Out:
# 98548

# %%
#Maximum value
data['rating'].max()
# Out:
# 5

# %%
#Minimum
data['rating'].min()
# Out:
# 1

# %%
#Standard Deviation
data['rating'].std()
# Out:
# 1.110030719824253

# %%
#Count
data['rating'].count()
# Out:
# 23486

# %%
# Cleaning of Dataset : In this stage start cleaning our dataset in order to continue the analysis.
# Handaling Missing Values

# %%
# Drop the serial no. as it is no use . Because index no. and serial no. is same .
data.drop('s.no', axis=1, inplace=True)
data
# Out:
#        age   division_name department_name class_name  clothing_id  \
# 0       40         General         Bottoms      Jeans         1028
# 1       62  General Petite            Tops    Blouses          850
# 2       47  General Petite         Bottoms     Skirts          993
# 3       45  General Petite         Bottoms      Pants         1068
# 4       37       Initmates        Intimate       Swim           24
# ...    ...             ...             ...        ...          ...
# 23481   44  General Petite         Dresses    Dresses         1081
# 23482   39         General         Dresses    Dresses         1110
# 23483   29  General Petite            Tops      Knits          862
# 23484   57         General         Dresses    Dresses         1082
# 23485   56         General         Jackets    Jackets          984
#
#                                        title  \
# 0                       Amazing fit and wash
# 1                         Lovely and unique!
# ...

# %%
#Checking the missing values
data.isnull()
# Out:
#          age  division_name  department_name  class_name  clothing_id  title  \
# 0      False          False            False       False        False  False
# 1      False          False            False       False        False  False
# 2      False          False            False       False        False  False
# 3      False          False            False       False        False  False
# 4      False          False            False       False        False  False
# ...      ...            ...              ...         ...          ...    ...
# 23481  False          False            False       False        False  False
# 23482  False          False            False       False        False  False
# 23483  False          False            False       False        False  False
# 23484  False          False            False       False        False  False
# 23485  False          False            False       False        False   True
#
# ...

# %%
# Total no. of missing Value
# Return a copy of the data with missing values filled 
data.isnull().sum()
# Out:
# age                        0
# division_name             14
# department_name           14
# class_name                14
# clothing_id                0
# title                   3810
# review_text              845
# alike_feedback_count       0
# rating                     0
# recommend_index            0
# dtype: int64

# %%
# sorting the missing value in decsending order
total=data.isnull().sum().sort_values(ascending=False)
total
# Out:
# title                   3810
# review_text              845
# division_name             14
# department_name           14
# class_name                14
# age                        0
# clothing_id                0
# alike_feedback_count       0
# rating                     0
# recommend_index            0
# dtype: int64

# %%
# Percentage of missing values per column
missing_percent=data.isnull().sum().sort_values(ascending=False)/len(data)
missing_percent
# Out:
# title                   0.162224
# review_text             0.035979
# division_name           0.000596
# department_name         0.000596
# class_name              0.000596
# age                     0.000000
# clothing_id             0.000000
# alike_feedback_count    0.000000
# rating                  0.000000
# recommend_index         0.000000
# dtype: float64

# %%
missing_data=pd.concat([total,missing_percent],axis=1,keys=['Total','Percentage'])
missing_data
# Out:
#                       Total  Percentage
# title                  3810    0.162224
# review_text             845    0.035979
# division_name            14    0.000596
# department_name          14    0.000596
# class_name               14    0.000596
# age                       0    0.000000
# clothing_id               0    0.000000
# alike_feedback_count      0    0.000000
# rating                    0    0.000000
# recommend_index           0    0.000000

# %%
bool_series=pd.isnull(data)
data[bool_series]
# Out:
#        age division_name department_name class_name  clothing_id title  \
# 0      NaN           NaN             NaN        NaN          NaN   NaN
# 1      NaN           NaN             NaN        NaN          NaN   NaN
# 2      NaN           NaN             NaN        NaN          NaN   NaN
# 3      NaN           NaN             NaN        NaN          NaN   NaN
# 4      NaN           NaN             NaN        NaN          NaN   NaN
# ...    ...           ...             ...        ...          ...   ...
# 23481  NaN           NaN             NaN        NaN          NaN   NaN
# 23482  NaN           NaN             NaN        NaN          NaN   NaN
# 23483  NaN           NaN             NaN        NaN          NaN   NaN
# 23484  NaN           NaN             NaN        NaN          NaN   NaN
# 23485  NaN           NaN             NaN        NaN          NaN   NaN
#
#       review_text  alike_feedback_count  rating  recommend_index
# ...

# %%
# Showing output only the output having Gender=Null are displayed
# return true for null value
bool_series=pd.isnull(data["division_name"])
data[bool_series]
# Out:
#        age division_name department_name class_name  clothing_id  \
# 593     34           NaN             NaN        NaN          184
# 2275    36           NaN             NaN        NaN          152
# 4349    43           NaN             NaN        NaN          665
# 4745    50           NaN             NaN        NaN          772
# 7589    39           NaN             NaN        NaN          152
# 8163    25           NaN             NaN        NaN           72
# 8333    36           NaN             NaN        NaN          136
# 14464   54           NaN             NaN        NaN          184
# 14670   49           NaN             NaN        NaN          492
# 15513   37           NaN             NaN        NaN          152
# 20789   47           NaN             NaN        NaN          136
# 22325   48           NaN             NaN        NaN          492
# 22679   33           NaN             NaN        NaN          136
# ...

# %%
bool_series=pd.notnull(data)
data[bool_series]
# Out:
#        age   division_name department_name class_name  clothing_id  \
# 0       40         General         Bottoms      Jeans         1028
# 1       62  General Petite            Tops    Blouses          850
# 2       47  General Petite         Bottoms     Skirts          993
# 3       45  General Petite         Bottoms      Pants         1068
# 4       37       Initmates        Intimate       Swim           24
# ...    ...             ...             ...        ...          ...
# 23481   44  General Petite         Dresses    Dresses         1081
# 23482   39         General         Dresses    Dresses         1110
# 23483   29  General Petite            Tops      Knits          862
# 23484   57         General         Dresses    Dresses         1082
# 23485   56         General         Jackets    Jackets          984
#
#                                        title  \
# 0                       Amazing fit and wash
# 1                         Lovely and unique!
# ...

# %%
# Showing only the row having division name=Not Null are displayed
bool_series=pd.notnull(data['division_name'])
data[bool_series]
# Out:
#        age   division_name department_name class_name  clothing_id  \
# 0       40         General         Bottoms      Jeans         1028
# 1       62  General Petite            Tops    Blouses          850
# 2       47  General Petite         Bottoms     Skirts          993
# 3       45  General Petite         Bottoms      Pants         1068
# 4       37       Initmates        Intimate       Swim           24
# ...    ...             ...             ...        ...          ...
# 23481   44  General Petite         Dresses    Dresses         1081
# 23482   39         General         Dresses    Dresses         1110
# 23483   29  General Petite            Tops      Knits          862
# 23484   57         General         Dresses    Dresses         1082
# 23485   56         General         Jackets    Jackets          984
#
#                                        title  \
# 0                       Amazing fit and wash
# 1                         Lovely and unique!
# ...

# %%
# Filling the missing values using fillna(),replace()

# %%
data1=data.fillna("Missing")
data1[30:40]
# Out:
#     age   division_name department_name class_name  clothing_id  \
# 30   42         General         Bottoms      Pants         1056
# 31   35         General         Bottoms      Pants         1063
# 32   56  General Petite            Tops      Knits          884
# 33   60         General         Bottoms      Pants         1058
# 34   75       Initmates        Intimate     Lounge          623
# 35   59         General            Tops    Blouses          836
# 36   35         General         Dresses    Dresses         1083
# 37   62         General            Tops      Knits          886
# 38   30  General Petite            Tops    Blouses          838
# 39   38  General Petite            Tops   Sweaters          939
#
#                                        title  \
# 30                           I "heart" this!
# 31                         Fabric is amazing
# 32  Top part is gorgeous; bottom part is not
# 33             Stylish, but has a few issues
# ...

# %%
data1=data.fillna(method='bfill')
data1[30:40]
# Out:
#     age   division_name department_name class_name  clothing_id  \
# 30   42         General         Bottoms      Pants         1056
# 31   35         General         Bottoms      Pants         1063
# 32   56  General Petite            Tops      Knits          884
# 33   60         General         Bottoms      Pants         1058
# 34   75       Initmates        Intimate     Lounge          623
# 35   59         General            Tops    Blouses          836
# 36   35         General         Dresses    Dresses         1083
# 37   62         General            Tops      Knits          886
# 38   30  General Petite            Tops    Blouses          838
# 39   38  General Petite            Tops   Sweaters          939
#
#                                        title  \
# 30                           I "heart" this!
# 31                         Fabric is amazing
# 32  Top part is gorgeous; bottom part is not
# 33             Stylish, but has a few issues
# ...

# %%
data1=data.fillna(method='pad')
data1[30:40]
# Out:
#     age   division_name department_name class_name  clothing_id  \
# 30   42         General         Bottoms      Pants         1056
# 31   35         General         Bottoms      Pants         1063
# 32   56  General Petite            Tops      Knits          884
# 33   60         General         Bottoms      Pants         1058
# 34   75       Initmates        Intimate     Lounge          623
# 35   59         General            Tops    Blouses          836
# 36   35         General         Dresses    Dresses         1083
# 37   62         General            Tops      Knits          886
# 38   30  General Petite            Tops    Blouses          838
# 39   38  General Petite            Tops   Sweaters          939
#
#                                        title  \
# 30                           I "heart" this!
# 31                         Fabric is amazing
# 32  Top part is gorgeous; bottom part is not
# 33             Stylish, but has a few issues
# ...

# %%
data2=data.replace(to_replace=np.nan,value='Fill something')
data2[30:40]
# Out:
#     age   division_name department_name class_name  clothing_id  \
# 30   42         General         Bottoms      Pants         1056
# 31   35         General         Bottoms      Pants         1063
# 32   56  General Petite            Tops      Knits          884
# 33   60         General         Bottoms      Pants         1058
# 34   75       Initmates        Intimate     Lounge          623
# 35   59         General            Tops    Blouses          836
# 36   35         General         Dresses    Dresses         1083
# 37   62         General            Tops      Knits          886
# 38   30  General Petite            Tops    Blouses          838
# 39   38  General Petite            Tops   Sweaters          939
#
#                                        title  \
# 30                           I "heart" this!
# 31                         Fabric is amazing
# 32  Top part is gorgeous; bottom part is not
# 33             Stylish, but has a few issues
# ...

# %%
new_data=data.dropna(axis=0,how='any')
new_data
# Out:
#        age   division_name department_name class_name  clothing_id  \
# 0       40         General         Bottoms      Jeans         1028
# 1       62  General Petite            Tops    Blouses          850
# 2       47  General Petite         Bottoms     Skirts          993
# 3       45  General Petite         Bottoms      Pants         1068
# 4       37       Initmates        Intimate       Swim           24
# ...    ...             ...             ...        ...          ...
# 23478   26         General            Tops      Knits          883
# 23481   44  General Petite         Dresses    Dresses         1081
# 23482   39         General         Dresses    Dresses         1110
# 23483   29  General Petite            Tops      Knits          862
# 23484   57         General         Dresses    Dresses         1082
#
#                                        title  \
# 0                       Amazing fit and wash
# 1                         Lovely and unique!
# ...

# %%
print("Old data length :",len(data))
print("New data length :",len(new_data))
print("No. of row with at least 1 Nan value :",(len(data)-len(new_data)))
# Out:
# Old data length : 23486
# New data length : 19662
# No. of row with at least 1 Nan value : 3824

# %%
# Dealing with missing data
# Return the filtered version of the data
data=data.dropna()
data
# Out:
#        age   division_name department_name class_name  clothing_id  \
# 0       40         General         Bottoms      Jeans         1028
# 1       62  General Petite            Tops    Blouses          850
# 2       47  General Petite         Bottoms     Skirts          993
# 3       45  General Petite         Bottoms      Pants         1068
# 4       37       Initmates        Intimate       Swim           24
# ...    ...             ...             ...        ...          ...
# 23478   26         General            Tops      Knits          883
# 23481   44  General Petite         Dresses    Dresses         1081
# 23482   39         General         Dresses    Dresses         1110
# 23483   29  General Petite            Tops      Knits          862
# 23484   57         General         Dresses    Dresses         1082
#
#                                        title  \
# 0                       Amazing fit and wash
# 1                         Lovely and unique!
# ...

# %%
data.isnull().sum()
# Out:
# age                     0
# division_name           0
# department_name         0
# class_name              0
# clothing_id             0
# title                   0
# review_text             0
# alike_feedback_count    0
# rating                  0
# recommend_index         0
# dtype: int64

# %%
# Checking the duplicate value
data.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 23478    False
# 23481    False
# 23482    False
# 23483    False
# 23484    False
# Length: 19662, dtype: bool

# %%
data.duplicated().sum()
# Out:
# 0

# %%
# Printing the total no. of unique value in the column
data.nunique()
# Out:
# age                        77
# division_name               3
# department_name             6
# class_name                 20
# clothing_id              1095
# title                   13983
# review_text             19656
# alike_feedback_count       79
# rating                      5
# recommend_index             2
# dtype: int64

# %%
# Printing the Unique value of Particular columns
print(data['recommend_index '].unique())
# Out:
# [1 0]

# %%
print(data['department_name'].unique())
# Out:
# ['Bottoms' 'Tops' 'Intimate' 'Dresses' 'Jackets' 'Trend']

# %%
print(data['class_name'].unique())
# Out:
# ['Jeans' 'Blouses' 'Skirts' 'Pants' 'Swim' 'Sweaters' 'Knits' 'Fine gauge'
#  'Dresses' 'Shorts' 'Jackets' 'Outerwear' 'Lounge' 'Intimates' 'Legwear'
#  'Trend' 'Sleep' 'Layering' 'Casual bottoms' 'Chemises']

# %%
print(data['title'].unique())
# Out:
# ['Amazing fit and wash' 'Lovely and unique!' 'Meh' ...
#  'I like the feel of the fabric but...' 'So soft and flattering'
#  'Another winner from isabella sinclair']

# %%
data
# Out:
#        age   division_name department_name class_name  clothing_id  \
# 0       40         General         Bottoms      Jeans         1028
# 1       62  General Petite            Tops    Blouses          850
# 2       47  General Petite         Bottoms     Skirts          993
# 3       45  General Petite         Bottoms      Pants         1068
# 4       37       Initmates        Intimate       Swim           24
# ...    ...             ...             ...        ...          ...
# 23478   26         General            Tops      Knits          883
# 23481   44  General Petite         Dresses    Dresses         1081
# 23482   39         General         Dresses    Dresses         1110
# 23483   29  General Petite            Tops      Knits          862
# 23484   57         General         Dresses    Dresses         1082
#
#                                        title  \
# 0                       Amazing fit and wash
# 1                         Lovely and unique!
# ...

# %%
# Exploratory data analysis using Visualization
# 1. Univariate analysis : In this we analyze data of one variable .
#    A variable in our dataset refers to a single column.

# %%
# Let's calculate the percentage of class_name of each columns
data.class_name.value_counts(normalize=True)
# plot the bar graph of % of class name category
data.class_name.value_counts(normalize=True).plot.barh()
# Out:
# <AxesSubplot:>

# %%
#  value_counts() : returns a series containing the counts of unique values in a particular columns.
data['department_name'].value_counts()
# Out:
# Tops        8713
# Dresses     5371
# Bottoms     3184
# Intimate    1408
# Jackets      879
# Trend        107
# Name: department_name, dtype: int64

# %%
# Countplot is used to show the total count of observation in the department_name
plt.figure(figsize=(10,7))
sns.countplot(x='department_name',data=data,order=data['department_name'].value_counts().index)
plt.xticks(rotation=60)
plt.show()

# %%
# Printing the total count of Rating column.
data['rating'].value_counts()
# Out:
# 5    10858
# 4     4289
# 3     2464
# 2     1360
# 1      691
# Name: rating, dtype: int64

# %%
# Histogram is used to count the no.of obseration in Rating colunm that fall in each bin .
sns.histplot(x='rating',data=data , kde=True)
# Out:
# <AxesSubplot:xlabel='rating', ylabel='Count'>

# %%
# Pie plot for the department name
plt.figure(figsize=(10,8))
data['department_name'].value_counts().plot.pie(autopct='%1.1f%%')
plt.show()

# %%
# Printing the total count of Division name .
data['division_name'].value_counts()
# Out:
# General           11664
# General Petite     6778
# Initmates          1220
# Name: division_name, dtype: int64

# %%
# Barplot for division_name  of cloth .
plt.figure(figsize=(8,4))
data['division_name'].value_counts().plot.bar(color='red')
plt.show()

# %%
# Pie plot for Division name .
data['division_name'].value_counts().plot.pie(autopct='%1.1f%%')
plt.show()

# %%
# 2. Bivariate Analysis

# %%
#Scatter plot
# Plot the sactter plot of the Age and  in data
plt.scatter(data.age,data.alike_feedback_count,color='green',marker='^')
plt.xlabel('Age')
plt.ylabel('Feedback Count')
plt.show()

# %%
#Scatter plot between Age and Department name
plt.scatter(x='department_name',y='age',data=data,c ="pink",
            linewidths = 4,marker ="*")
plt.xlabel('Department name of Cloth')
plt.ylabel('Age of person')
plt.show()

# %%
#Boxplot of rating for Division name sperately
sns.boxplot(x='division_name',y='rating',data=data)
plt.show()

# %%
# Barplot Between Division name and Department name
sns.barplot(x='division_name',y='alike_feedback_count',data=data,palette='rainbow',alpha=1)
plt.title('Relationship b/w Division of cloth and Feedback count')
plt.show()

# %%
# Boxplot to analyze the relationship between Rating and Cloth id
sns.boxplot(x='rating',y='clothing_id',data=data)
plt.show()

# %%
# Stripplot is used here to analyze the categorical i.e. Division name and total feedback value for each .
sns.stripplot(x='division_name',y='alike_feedback_count',data=data)
plt.show()

# %%
# Using groupby function
data.groupby('division_name')[['rating','alike_feedback_count']].sum().plot.bar(color=['green','skyblue'],
                                                                                alpha=0.7,figsize=(6,4))
plt.xlabel('Division name of cloth')
plt.ylabel('Rating and Feedback')
plt.show()

# %%
# groupby department_name to find the mean of rating separetely
data.groupby('department_name')['rating'].mean()
# Out:
# department_name
# Bottoms     4.287688
# Dresses     4.137032
# Intimate    4.257812
# Jackets     4.270762
# Tops        4.156433
# Trend       3.859813
# Name: rating, dtype: float64

# %%
# groupby department_name to find the median of rating for each separetely
data.groupby('department_name')['rating'].median()
# Out:
# department_name
# Bottoms     5.0
# Dresses     5.0
# Intimate    5.0
# Jackets     5.0
# Tops        5.0
# Trend       4.0
# Name: rating, dtype: float64

# %%
# Boxplot between department and Rating for each 
sns.boxplot(x='department_name',y='rating',data=data)
plt.show()

# %%
# groupby the class_name to find the sum/total of rating and alike_feedback_count separetely .
df=data.groupby('class_name')[['rating','alike_feedback_count']].sum().sort_values(by='rating',ascending=False)
df[:].plot.bar(color=['orange','brown'],alpha=0.8,figsize=(8,6))
plt.title('Rating and feedback of Each Cloth')
plt.xlabel('Cloth name')
plt.ylabel('Rating and Feedback')
plt.show()

# %%
# Printing the top 5 highest value of items from class_name
more_sale=data['class_name'].value_counts().nlargest(5)
more_sale
# Out:
# Dresses     5371
# Knits       3981
# Blouses     2587
# Sweaters    1218
# Pants       1157
# Name: class_name, dtype: int64

# %%
# Line plot between rating and feedback
sns.lineplot(x='rating',y='alike_feedback_count',label='Feedback count',data=data)
plt.legend()
plt.show()

# %%
# 3. Multivarient Analysis
# Pairplot 
# Heatmap

# %%
data.describe()
# Out:
#                 age   clothing_id  alike_feedback_count        rating  \
# count  19662.000000  19662.000000          19662.000000  19662.000000
# mean      43.260808    921.297274              2.652477      4.183145
# std       12.258122    200.227528              5.834285      1.112224
# min       18.000000      1.000000              0.000000      1.000000
# 25%       34.000000    861.000000              0.000000      4.000000
# 50%       41.000000    936.000000              1.000000      5.000000
# 75%       52.000000   1078.000000              3.000000      5.000000
# max       99.000000   1205.000000            122.000000      5.000000
#
#        recommend_index
# count      19662.000000
# mean           0.818177
# std            0.385708
# min            0.000000
# 25%            1.000000
# 50%            1.000000
# 75%            1.000000
# max            1.000000

# %%
corr=data.corr()
sns.heatmap(corr,annot=True,cmap='Reds')
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(data)

# %%
sns.pairplot(data,hue='division_name')

# %%
#Pair plot
sns.pairplot(data=data,vars=['age','rating','clothing_id'])
plt.show()

# %%
#Histogram plot to analyze the all data
data.hist(figsize=(10,10),bins=50)
plt.show()

# %%
num_feature=data.select_dtypes(include=[np.int])
num_feature.columns
# Out:
# C:\Users\Archana\AppData\Local\Temp\ipykernel_30812\68474495.py:1: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   num_feature=data.select_dtypes(include=[np.int])
# Index(['age', 'clothing_id', 'alike_feedback_count', 'rating',
#        'recommend_index '],
#       dtype='object')

# %%
for i in num_feature:
    plt.figure()
    plt.tight_layout()
    sns.set(rc={"figure.figsize":(10,7)})
    f,(ax_box,ax_hist)=plt.subplots(2,sharex=True)
    plt.gca().set(xlabel=i,ylabel='Frequency')
    sns.boxplot(data[i],ax=ax_box,linewidth=2)
    sns.histplot(data[i],ax=ax_hist,bins=5,kde=True)
# Out:
# C:\Users\Archana\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Archana\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Archana\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...
